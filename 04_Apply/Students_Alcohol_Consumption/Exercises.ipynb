# %% [markdown]
# <a href="https://colab.research.google.com/github/03dipak/practise-pandas-ml/blob/master/04_Apply/Students_Alcohol_Consumption/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv",sep=',')
df.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
school_df = df.loc[:,'school':'guardian']
school_df.head()
# Out:
#   school sex  age address famsize  ... Fedu     Mjob      Fjob  reason guardian
# 0     GP   F   18       U     GT3  ...    4  at_home   teacher  course   mother
# 1     GP   F   17       U     GT3  ...    1  at_home     other  course   father
# 2     GP   F   15       U     LE3  ...    1  at_home     other   other   mother
# 3     GP   F   15       U     GT3  ...    2   health  services    home   mother
# 4     GP   F   16       U     GT3  ...    3    other     other    home   father
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Step 5. Create a lambda function that capitalize strings.

# %%
capFunct =  lambda x: x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
school_df.Fjob.apply(capFunct)
school_df.Mjob.apply(capFunct)
# Out:
# 0       At_home
# 1       At_home
# 2       At_home
# 3        Health
# 4         Other
# 5      Services
# 6         Other
# 7         Other
# 8      Services
# 9         Other
# 10      Teacher
# 11     Services
# 12       Health
# 13      Teacher
# 14        Other
# 15       Health
# 16     Services
# 17        Other
# 18     Services
# 19       Health
# 20      Teacher
# 21       Health
# 22      Teacher
# 23        Other
# 24     Services
# 25     Services
# 26        Other
# 27       Health
# 28     Services
# 29      Teacher
#          ...
# 365     At_home
# 366     Teacher
# 367       Other
# 368     At_home
# 369       Other
# 370    Services
# 371     At_home
# 372       Other
# 373       Other
# 374       Other
# 375       Other
# 376      Health
# 377     Teacher
# 378       Other
# 379     At_home
# 380     Teacher
# 381       Other
# 382       Other
# 383       Other
# 384       Other
# 385     At_home
# 386     Teacher
# 387    Services
# 388     Teacher
# ...

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
school_df.tail()
# Out:
#     school sex  age address famsize  ... Fedu      Mjob      Fjob  reason guardian
# 390     MS   M   20       U     LE3  ...    2  services  services  course    other
# 391     MS   M   17       U     LE3  ...    1  services  services  course   mother
# 392     MS   M   21       R     GT3  ...    1     other     other  course    other
# 393     MS   M   18       R     LE3  ...    2  services     other  course   mother
# 394     MS   M   19       U     LE3  ...    1     other   at_home  course   father
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
school_df.Fjob = school_df.Fjob.apply(capFunct)
school_df.Mjob = school_df.Mjob.apply(capFunct)

school_df.tail()
# Out:
#     school sex  age address famsize  ... Fedu      Mjob      Fjob  reason guardian
# 390     MS   M   20       U     LE3  ...    2  Services  Services  course    other
# 391     MS   M   17       U     LE3  ...    1  Services  Services  course   mother
# 392     MS   M   21       R     GT3  ...    1     Other     Other  course    other
# 393     MS   M   18       R     LE3  ...    2  Services     Other  course   mother
# 394     MS   M   19       U     LE3  ...    1     Other   At_home  course   father
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(x):
  """
  function retrurn True id age is greater than 17
  """
  if x > 17:
    return True
  else:
    return False

# %%
school_df['legal_drinker'] = school_df.age.apply(majority)

school_df.tail()
# Out:
#     school sex  age address  ...      Fjob  reason  guardian  legal_drinker
# 390     MS   M   20       U  ...  Services  course     other           True
# 391     MS   M   17       U  ...  Services  course    mother          False
# 392     MS   M   21       R  ...     Other  course     other           True
# 393     MS   M   18       R  ...     Other  course    mother           True
# 394     MS   M   19       U  ...   At_home  course    father           True
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
def multiFunctio(x):
  """
  function multiply int value by 10
  """
  if type(x) is int:
    return x * 10
  return x

# %%
school_df.applymap(multiFunctio).head()

#school_df.head()
# Out:
#   school sex  age address  ...      Fjob  reason  guardian  legal_drinker
# 0     GP   F  180       U  ...   Teacher  course    mother           True
# 1     GP   F  170       U  ...     Other  course    father          False
# 2     GP   F  150       U  ...     Other   other    mother          False
# 3     GP   F  150       U  ...  Services    home    mother          False
# 4     GP   F  160       U  ...     Other    home    father          False
#
# [5 rows x 13 columns]
